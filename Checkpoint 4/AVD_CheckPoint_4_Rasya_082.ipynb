# %% [markdown]
# # **CheckPoint 1**

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = '/content/global_climate_change_extreme_weather_2026.csv'
df = pd.read_csv(file)

# %% [markdown]
# # **Memuat Data**

# %%
df
# Out:
#      record_id         country         region  avg_temperature_c  \
# 0      CLM0001          Canada  North America               16.8
# 1      CLM0002          Brazil  South America               28.8
# 2      CLM0003       Australia        Oceania                6.6
# 3      CLM0004         Germany         Europe               10.9
# 4      CLM0005   United States  North America               13.9
# ...        ...             ...            ...                ...
# 4995   CLM4996          Brazil  South America               18.4
# 4996   CLM4997          Canada  North America                8.5
# 4997   CLM4998  United Kingdom         Europe               19.4
# 4998   CLM4999           China           Asia               13.7
# 4999   CLM5000  United Kingdom         Europe                7.2
#
#       temperature_change_c  co2_emissions_mt  sea_level_rise_mm flood_risk  \
# 0                     2.40              5477               1.44        Low
# ...

# %% [markdown]
# # **BUSINESS UNDERSTANDING**

# %% [markdown]
# **BUSINESS OBJECTIVE**

# %% [markdown]
# Business Objective dari analisis dataset perubahan iklim ini untuk mengidentifikasi dan evaluasi resiko perubahan iklim di berbagai negara seperti emisi CO₂, perubahan suhu, kenaikan permukaan laut dan dampaknya terhadap populasi.
# Tujuan yang ingin dicapai adalah:
# 1. Menentukan negara atau wilayah dengan tingkat climate risk score tertinggi.
# 2. Mengidentifikasi faktor-faktor utama yang berkontribusi terhadap tingginya risiko iklim.
# 3. Mendukung perumusan strategi mitigasi dan kebijakan lingkungan yang lebih efektif berbasis data.
#
# Dengan ini, hasil analisis yang diharapkan dapat membantu pengambil keputusan dalam meminimalkan dampak sosial dan ekonomi akibat perubahan iklim.

# %% [markdown]
# **ASSESS SITUATION**

# %% [markdown]
# Saat ini resiko perubahan iklim di berbagai negara semakin meningkat ditandai dengan kenaikan suhu, emisi CO₂, perubahan curah hujan, serta meningkatnya kejadian banjir, kekeringan, dan gelombang panas yang berdampaknya pada populasi
#
# Dataset yang tersedia memuat berbagai indikator iklim dan skor risiko yang dapat digunakan untuk menganalisis tingkat kerentanan suatu negara. Namun, terdapat kemungkinan kendala seperti variasi data antarnegara dan kompleksitas hubungan antarvariabel, sehingga diperlukan analisis yang sistematis agar hasilnya akurat dan relevan untuk mendukung pengambilan keputusan

# %% [markdown]
# **ANALYTIC GOALS**

# %% [markdown]
# Tujuan analitik dalam penelitian ini adalah:
#
# 1. Menganalisis tingkat climate risk score di berbagai negara
# 2. Mengidentifikasi faktor-faktor yang paling berpengaruh terhadap risiko perubahan iklim, seperti emisi CO₂, perubahan suhu, dan kenaikan permukaan laut
#
# 3. Menganalisis hubungan antara indikator perubahan iklim dengan jumlah populasi terdampak
#
# 4. Mengelompokkan negara berdasarkan tingkat risiko iklim

# %% [markdown]
# **PROJECT PLANS**

# %% [markdown]
# rencana proyek sendiri dalam analisis perubahan iklim ini adalah:
#
# 1. Data Understanding: memahami struktur dataset, jenis variabel, dan hubungan antarindikator perubahan iklim
#
# 2. Data Preparation: membersihkan data, menangani nilai yang hilang, serta menyiapkan variabel yang relevan untuk analisis
#
# 3. Data Analysis: melakukan analisis deskriptif dan eksploratif untuk melihat pola, tren, serta hubungan antarvariabel seperti emisi CO₂, perubahan suhu, dan climate risk score
#
# 4. Modeling: sebenernya opsional, modeling sendiri buat membangun model untuk mengidentifikasi faktor dominan atau mengelompokkan negara berdasarkan tingkat resiko
#
# 5. Evaluation & Reporting: mengevaluasi hasil analisis dan menyusun rekomendasi yang dapat mendukung pengambilan keputusan terkait mitigasi perubahan iklim
#
# Rencana ini disusun supaya proses analisis ini berjalan sistematis dan menghasilkan insight yang relevan bagi kebutuhan bisnis

# %% [markdown]
# # **CheckPoint 2**

# %% [markdown]
# # **Data UnderStanding**

# %% [markdown]
# ### **Struktur Data (Informasi Lanjutan)**

# %%
import pandas as pd

df = pd.read_csv('global_climate_change_extreme_weather_2026.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   record_id              5000 non-null   object
#  1   country                5000 non-null   object
#  2   region                 5000 non-null   object
#  3   avg_temperature_c      5000 non-null   float64
#  4   temperature_change_c   5000 non-null   float64
#  5   co2_emissions_mt       5000 non-null   int64
#  6   sea_level_rise_mm      5000 non-null   float64
#  7   flood_risk             5000 non-null   object
#  8   drought_risk           5000 non-null   object
#  9   heatwave_days          5000 non-null   int64
#  10  wildfire_incidents     5000 non-null   int64
#  11  rainfall_change_mm     5000 non-null   int64
#  12  air_quality_index      5000 non-null   int64
#  13  climate_risk_score     5000 non-null   int64
# ...

# %% [markdown]
# 1. record_id: 0
#
#
# *   Jumlah baris: 5000
# *   Tipe data: object
# * Deskripsi: ID unik untuk setiap data/record
#
#
#
#
# 2. country: 5000
# * Jumlah baris: 5000
# * Tipe data: object
# * Deskripsi: Nama negara
#
# 3. region: 5000
# * Jumlah baris: 5000
# * Tipe data: object
# * Deskripsi: Wilayah atau kawasan negara
#
# 4. avg_temperature_c: 5000
# * Jumlah baris: 5000
# * Tipe data: float64
# * Deskripsi: Rata-rata suhu dalam derajat Celsius
#
# 5. temperature_change_c: 5000
# * Jumlah baris: 5000
# * Tipe data: float64
# * Deskripsi: Perubahan suhu dalam derajat Celsius
#
# 6. co2_emissions_mt: 5000
# * Jumlah baris: 5000
# * Tipe data: int64
# * Deskripsi: Jumlah emisi CO₂ dalam metrik ton
#
# 7. sea_level_rise_mm: 5000
# * Jumlah baris: 5000
# * Tipe data: float64
# * Deskripsi: Kenaikan permukaan laut dalam milimeter
#
# 8. flood_risk: 5000
# * Jumlah baris: 5000
# * Tipe data: object
# * Deskripsi: Tingkat risiko banjir
#
# 9. drought_risk: 5000
# * Jumlah baris: 5000
# * Tipe data: object
# * Deskripsi: Tingkat risiko kekeringan
#
# 10. heatwave_days: 5000
# * Jumlah baris: 5000
# * Tipe data: int64
# * Deskripsi: Jumlah hari gelombang panas
#
# 11. wildfire_incidents: 5000
# * Jumlah baris: 5000
# * Tipe data: int64
# * Deskripsi: Jumlah kejadian kebakaran hutan
#
# 12. rainfall_change_mm: 5000
# * Jumlah baris: 5000
# * Tipe data: int64
# * Deskripsi: Perubahan curah hujan dalam milimeter
#
# 13. air_quality_index: 5000
# * Jumlah baris: 5000
# * Tipe data: int64
# * Deskripsi: Indeks kualitas udara
#
# 14. climate_risk_score: 5000
# * Jumlah baris: 5000
# * Tipe data: int64
# * Deskripsi: Skor tingkat risiko perubahan iklim
#
# 15. population_affected_m: 5000
# * Jumlah baris: 5000
# * Tipe data: float64
# * Deskripsi: Jumlah populasi terdampak (dalam juta)
#
# 16. year: 5000
# * Jumlah baris: 5000
# * Tipe data: int64
# * Deskripsi: Tahun pencatatan data

# %% [markdown]
# ### **Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#        record_id  country region  avg_temperature_c  temperature_change_c  \
# count       5000     5000   5000        5000.000000           5000.000000
# unique      5000       10      6                NaN                   NaN
# top      CLM5000  Germany   Asia                NaN                   NaN
# freq           1      542   1453                NaN                   NaN
# mean         NaN      NaN    NaN          17.491040              1.493576
# std          NaN      NaN    NaN           7.203599              0.576416
# min          NaN      NaN    NaN           5.000000              0.500000
# 25%          NaN      NaN    NaN          11.300000              0.990000
# 50%          NaN      NaN    NaN          17.400000              1.480000
# 75%          NaN      NaN    NaN          23.800000              1.990000
# max          NaN      NaN    NaN          30.000000              2.500000
#
#         co2_emissions_mt  sea_level_rise_mm flood_risk drought_risk  \
# ...

# %% [markdown]
# 1. Count (Kelengkapan Data)
#
# Berdasarkan hasil deskripsi data, total baris pada dataset adalah 5.000. Seluruh kolom memiliki nilai count sebesar 5.000.
#
# Kesimpulan:
# Tidak terdapat missing values pada dataset karena setiap kolom berisi 5.000 data lengkap. Dataset dapat dikatakan bersih dan siap digunakan untuk analisis lebih lanjut.
#
#
#
# 2. Mean vs Median (Distribusi Data)
#
# Kolom Avg Temperature (°C)
#
# * Mean = 17,49
# * Median = 17,40
#
# Nilai rata-rata hampir sama dengan median, sehingga distribusi suhu rata-rata cenderung simetris dan tidak menunjukkan skewness yang signifikan.
#
# Kolom CO2 Emissions (mt)
#
# * Mean = 3145,74
# * Median = 3173,00
#
# Perbedaan antara mean dan median relatif kecil, menunjukkan distribusi emisi karbon cukup stabil dan tidak terlalu dipengaruhi oleh outlier ekstrem.
#
# Kolom Sea Level Rise (mm)
#
# * Mean = 3,50
# * Median = 3,52
#
# Nilai mean dan median yang hampir sama menunjukkan distribusi kenaikan permukaan laut cenderung normal atau simetris.
#
# Kolom Heatwave Days
#
# * Mean = 32,41
# * Median = 32,00
#
# Perbedaan yang sangat kecil antara mean dan median menunjukkan jumlah hari gelombang panas tersebar cukup merata.
#
# Kolom Climate Risk Score
#
# * Mean = 57,60
# * Median = 58,00
#
# Distribusi skor risiko iklim relatif seimbang dan tidak condong ke salah satu sisi.
#
# Kesimpulan:
# Secara umum, variabel numerik dalam dataset ini memiliki nilai mean yang sangat dekat dengan median, sehingga distribusi data cenderung normal atau simetris dan tidak menunjukkan skewness yang signifikan.
#
#
#
# 3. Min dan Max (Validasi Logika)
#
# Kolom Avg Temperature (°C)
#
# * Min = 5
# * Max = 30
#
# Rentang suhu ini masih dalam batas logis untuk variasi suhu rata-rata global.
#
# Kolom CO2 Emissions (mt)
#
# * Min = 301
# * Max = 5999
#
# Rentang ini menunjukkan variasi antar negara yang cukup besar namun masih masuk akal secara logika.
#
# Kolom Sea Level Rise (mm)
#
# * Min = 1
# * Max = 6
#
# Nilai kenaikan permukaan laut berada dalam rentang realistis untuk skenario perubahan iklim tahunan.
#
# Kolom Heatwave Days
#
# * Min = 5
# * Max = 60
#
# Menunjukkan adanya variasi signifikan antar wilayah dalam jumlah hari gelombang panas.
#
# Kolom Climate Risk Score
#
# * Min = 20
# * Max = 95
#
# Skor berada dalam rentang yang wajar untuk indeks risiko dengan skala 0–100.
#
# Kesimpulan:
# Seluruh nilai minimum dan maksimum berada dalam rentang yang logis dan realistis. Tidak terdapat indikasi kesalahan input data.
#
#
#
# 4. Standar Deviasi (Std) – Variabilitas Data
#
# Kolom CO2 Emissions (mt)
#
# * Mean = 3145,74
# * Std = 1640,11
#
# Nilai standar deviasi yang cukup besar dibandingkan mean menunjukkan adanya variasi signifikan emisi antar negara.
#
# Kolom Heatwave Days
#
# * Mean = 32,41
# * Std = 16,26
#
# Standar deviasi yang relatif tinggi menunjukkan perbedaan jumlah hari gelombang panas yang cukup besar antar wilayah.
#
# Kolom Climate Risk Score
#
# * Mean = 57,60
# * Std = 22,03
#
# Hal ini mengindikasikan adanya perbedaan tingkat risiko iklim yang signifikan antar negara atau region.
#
# Kesimpulan:
# Beberapa variabel memiliki standar deviasi yang cukup tinggi, yang menunjukkan adanya variasi atau ketimpangan dampak perubahan iklim antar wilayah dalam dataset ini.

# %% [markdown]
# ## **Verifikasi Kualitas Data**

# %% [markdown]
# **Data Types Check**

# %%
df.dtypes
# Out:
# record_id                 object
# country                   object
# region                    object
# avg_temperature_c        float64
# temperature_change_c     float64
# co2_emissions_mt           int64
# sea_level_rise_mm        float64
# flood_risk                object
# drought_risk              object
# heatwave_days              int64
# wildfire_incidents         int64
# rainfall_change_mm         int64
# air_quality_index          int64
# climate_risk_score         int64
# population_affected_m    float64
# year                       int64
# dtype: object

# %% [markdown]
# **Kesimpulan:**
#
# dataset memiliki tipe data yang sudah sesuai dengan jenis variabelnya, di mana kolom seperti record_id, country, region, flood_risk, dan drought_risk bertipe object (kategorikal/teks), beberapa kolom seperti avg_temperature_c, temperature_change_c, sea_level_rise_mm dan population_affected_m bertipe float64 (numerik desimal), serta kolom lainnya seperti co2_emissions_mt, heatwave_days, wildfire_incidents, rainfall_change_mm, air_quality_index, climate_risk_score, dan year bertipe int64 (numerik bilangan bulat). Secara keseluruhan, struktur tipe data sudah tepat dan siap digunakan untuk analisis lebih lanjut tanpa perlu konversi tambahan

# %% [markdown]
# ## **Incosistent Values**

# %% [markdown]
# Ditahap ini, kita perlu mengecek kekonsistenan data kita, contoh nya dalam penulisan. Hal ini dilakukan agar data tidak terduplikat dengan baris yang sebenarnya sama akan tetapi bisa terduplikat karena tidak konsisten

# %% [markdown]
# **1. record_id**
#
# Kolom record_id sudah bersih dari inkonsistensi data karena setiap nilai bersifat unik (tidak ada duplikasi) dan tidak terdapat nilai kosong. Format penulisan juga seragam sehingga dapat digunakan sebagai identitas utama data

# %%
print(df['record_id'].unique())
# Out:
# ['CLM0001' 'CLM0002' 'CLM0003' ... 'CLM4998' 'CLM4999' 'CLM5000']

# %% [markdown]
# **2. Country**
#
# Kolom country sudah konsisten karena hanya berisi nama negara yang valid dengan jumlah kategori terbatas dan tidak terdapat perbedaan penulisan (misalnya huruf besar/kecil atau typo

# %%
print(df['country'].unique())
# Out:
# ['Canada' 'Brazil' 'Australia' 'Germany' 'United States' 'United Kingdom'
#  'Nigeria' 'Pakistan' 'China' 'India']

# %% [markdown]
# ## **Missing Value**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                        Null Ratio in %
# record_id                          0.0
# country                            0.0
# region                             0.0
# avg_temperature_c                  0.0
# temperature_change_c               0.0
# co2_emissions_mt                   0.0
# sea_level_rise_mm                  0.0
# flood_risk                         0.0
# drought_risk                       0.0
# heatwave_days                      0.0
# wildfire_incidents                 0.0
# rainfall_change_mm                 0.0
# air_quality_index                  0.0
# climate_risk_score                 0.0
# population_affected_m              0.0
# year                               0.0

# %% [markdown]
# **Kesimpulan:**
#
# berdasarkan hasil pengecekan, semua kolom memiliki nilai 0.0% sehingga tidak terdapat missing values pada dataset

# %% [markdown]
# ## **Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [record_id, country, region, avg_temperature_c, temperature_change_c, co2_emissions_mt, sea_level_rise_mm, flood_risk, drought_risk, heatwave_days, wildfire_incidents, rainfall_change_mm, air_quality_index, climate_risk_score, population_affected_m, year]
# Index: []

# %% [markdown]
# **Kesimpulan:**
#
# berdasarkan hasil pengecekan yang menunjukkan *No entries*, dapat disimpulkan bahwa tidak terdapat duplicated values pada dataset

# %% [markdown]
# ## **Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

#Dataframe dari list hasil

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

#Tampilkan dataframe

display(results_df)
# Out:
# Kolom                  Persentase Outliers
# avg_temperature_c                      0.0
# temperature_change_c                   0.0
# co2_emissions_mt                       0.0
# sea_level_rise_mm                      0.0
# heatwave_days                          0.0
# wildfire_incidents                     0.0
# rainfall_change_mm                     0.0
# air_quality_index                      0.0
# climate_risk_score                     0.0
# population_affected_m                  0.0
# year                                   0.0

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['co2_emissions_mt'])
plt.title('Boxplot of co2_emissions_mt')
plt.ylabel('co2_emissions_mt')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['temperature_change_c'])
plt.title('Boxplot of temperature_change_c)')
plt.ylabel('temperature_change_c')
plt.show()

# %% [markdown]
# **Kesimpulan:**
#
# 1. Boxplot *co2_emissions_mt* menunjukkan rentang dan variasi data yang luas dengan median sekitar 3100, menandakan perbedaan emisi yang cukup besar antar data
# 2.  Boxplot *temperature_change_c *memiliki rentang lebih sempit dengan median sekitar 1,4–1,5 °C, menunjukkan perubahan suhu yang lebih stabil, sehingga secara umum emisi CO₂ lebih bervariasi dibandingkan perubahan suhu

# %% [markdown]
# # **Eksplorasi Data EDA**

# %% [markdown]
# ## **Comparison(Perbandingan)**

# %%
perbandingan_region = df.groupby('region')['climate_risk_score'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))

sns.barplot(x=perbandingan_region.index, y=perbandingan_region.values, palette='viridis', hue=perbandingan_region.index)
plt.title('Rata-rata Climate Risk Score Berdasarkan Region')
plt.xlabel('region')
plt.ylabel('Rata-rata Climate Risk Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Kesimpulan:**
#
# grafik menunjukkan bahwa Asia memiliki rata-rata Climate Risk Score tertinggi, disusul oleh Eropa dan Amerika Utara dengan nilai yang tidak jauh berbeda, sedangkan Amerika Selatan, Oseania, dan Afrika memiliki skor yang lebih rendah dan relatif mirip satu sama lain

# %% [markdown]
# ## **Composition/Komposisi**

# %%
risk_by_region = df.groupby('region')['climate_risk_score'].mean().sort_values(ascending=False)
risk_by_region_top3 = risk_by_region.head(3)

plt.figure(figsize=(10, 8))
risk_by_region_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi 3 Region dengan Climate Risk Score Tertinggi')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# **Kesimpulan:**
#
# diagram pie menunjukkan bahwa tiga region dengan Climate Risk Score tertinggi—Asia, Afrika, dan Amerika Utara—memiliki proporsi yang hampir sama, masing-masing sekitar 33%, sehingga kontribusi ketiganya relatif seimbang tanpa perbedaan yang signifikan

# %% [markdown]
# ## **Distribution/Distribusi**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['climate_risk_score'], bins=20, kde=True)
plt.title('Distribusi Climate Risk Score')
plt.xlabel('Climate Risk Score')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# **Kesimpulan:**
#
# histogram menunjukkan bahwa Climate Risk Score tersebar cukup merata pada rentang sekitar 20 hingga 95, tanpa lonjakan yang terlalu ekstrem di satu titik tertentu, sehingga distribusinya relatif stabil dengan kecenderungan peningkatan frekuensi pada nilai menengah hingga tinggi

# %% [markdown]
# ## **Relationship/Hubungan**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['co2_emissions_mt', 'climate_risk_score']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara CO2 Emissions dan Climate Risk Score')
plt.show()

# %% [markdown]
# **Kesimpulan:**
#
# heatmap menunjukkan bahwa korelasi antara CO2 Emissions dan Climate Risk Score sangat lemah (sekitar 0,01), sehingga hampir tidak ada hubungan linear yang signifikan antara kedua variabel tersebut, artinya tingginya emisi CO₂ tidak secara langsung berkorelasi kuat dengan tinggi rendahnya Climate Risk Score dalam data ini

# %% [markdown]
# # **Checkpoint 3**

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Mengecek Tipe Data**

# %%
df.dtypes
# Out:
# record_id                 object
# country                   object
# region                    object
# avg_temperature_c        float64
# temperature_change_c     float64
# co2_emissions_mt           int64
# sea_level_rise_mm        float64
# flood_risk                object
# drought_risk              object
# heatwave_days              int64
# wildfire_incidents         int64
# rainfall_change_mm         int64
# air_quality_index          int64
# climate_risk_score         int64
# population_affected_m    float64
# year                       int64
# dtype: object

# %% [markdown]
# ## **Mengidentifikasi Inconsistent Values**

# %%
print(df['region'].unique())
# Out:
# ['North America' 'South America' 'Oceania' 'Europe' 'Africa' 'Asia']

# %%
print(df['country'].unique())
# Out:
# ['Canada' 'Brazil' 'Australia' 'Germany' 'United States' 'United Kingdom'
#  'Nigeria' 'Pakistan' 'China' 'India']

# %%
print(df['flood_risk'].unique())
# Out:
# ['Low' 'Medium' 'High']

# %%
print(df['drought_risk'].unique())
# Out:
# ['High' 'Medium' 'Low']

# %% [markdown]
# berdasarkan pengecekan menggunakan fungsi unique() pada kolom country, region, flood_risk, dan drought_risk, tidak ditemukan perbedaan penulisan kategori, kesalahan pengetikan (typo), maupun variasi huruf besar/kecil. Seluruh nilai pada kolom-kolom tersebut ditulis secara konsisten. Dengan demikian, tidak terdapat inconsistent values pada kolom kategorikal dalam dataset

# %% [markdown]
# ## **Mengidentifikasi Missing Values.**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                        Null Ratio in %
# record_id                          0.0
# country                            0.0
# region                             0.0
# avg_temperature_c                  0.0
# temperature_change_c               0.0
# co2_emissions_mt                   0.0
# sea_level_rise_mm                  0.0
# flood_risk                         0.0
# drought_risk                       0.0
# heatwave_days                      0.0
# wildfire_incidents                 0.0
# rainfall_change_mm                 0.0
# air_quality_index                  0.0
# climate_risk_score                 0.0
# population_affected_m              0.0
# year                               0.0

# %% [markdown]
# pengecekan missing values dilakukan dengan menghitung persentase nilai kosong pada setiap kolom menggunakan rumus df.isna().sum() / len(df) * 100. Hasil perhitungan menunjukkan bahwa seluruh kolom memiliki nilai 0.0%, yang berarti tidak terdapat data yang hilang dalam dataset

# %% [markdown]
# ## **Mengidentifikasi Duplicated Values.**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [record_id, country, region, avg_temperature_c, temperature_change_c, co2_emissions_mt, sea_level_rise_mm, flood_risk, drought_risk, heatwave_days, wildfire_incidents, rainfall_change_mm, air_quality_index, climate_risk_score, population_affected_m, year]
# Index: []

# %% [markdown]
# hasil menunjukkan tidak terdapat baris data yang terduplikasi dalam dataset

# %% [markdown]
# ## **Mengidentifikasi Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

#Dataframe dari list hasil

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

#Tampilkan dataframe

display(results_df)
# Out:
# Kolom                  Persentase Outliers
# avg_temperature_c                      0.0
# temperature_change_c                   0.0
# co2_emissions_mt                       0.0
# sea_level_rise_mm                      0.0
# heatwave_days                          0.0
# wildfire_incidents                     0.0
# rainfall_change_mm                     0.0
# air_quality_index                      0.0
# climate_risk_score                     0.0
# population_affected_m                  0.0
# year                                   0.0

# %% [markdown]
# berdasarkan hasil pengecekan pada tabel persentase pencilan, data ini dinyatakan tidak memiliki outliers karena seluruh variabel menunjukkan angka 0.0

# %% [markdown]
# # **Data Reduction**

# %%
df_reduced = df.drop(columns=['record_id'])
df_reduced.head()
# Out:
#          country         region  avg_temperature_c  temperature_change_c  \
# 0         Canada  North America               16.8                  2.40
# 1         Brazil  South America               28.8                  1.51
# 2      Australia        Oceania                6.6                  1.70
# 3        Germany         Europe               10.9                  1.53
# 4  United States  North America               13.9                  2.07
#
#    co2_emissions_mt  sea_level_rise_mm flood_risk drought_risk  heatwave_days  \
# 0              5477               1.44        Low         High              9
# 1              3758               1.55     Medium       Medium             38
# 2              1904               5.81     Medium       Medium             20
# 3              3786               5.41     Medium          Low             56
# 4               732               3.20       High         High             42
#
# ...

# %% [markdown]
# proses data reduction dilakukan dengan menghapus kolom record_id menggunakan perintah df.drop(columns=['record_id']). Kolom tersebut dihapus karena hanya berfungsi sebagai identitas unik setiap data dan tidak memiliki pengaruh terhadap proses analisis

# %% [markdown]
# # **Construct Data**

# %% [markdown]
# Construct Data merupakan proses pembuatan variabel baru dari data yang sudah ada untuk mendukung analisis. Pada dataset ini tidak dilakukan proses construct data karena seluruh variabel yang tersedia sudah representatif dan dapat digunakan secara langsung dalam analisis

# %% [markdown]
# # **Menyimpan Dataset**

# %%
df.to_csv('global_climate_change_extreme_weather_2026.csv', index=False)

# %% [markdown]
# # **Checkpoint 4**

# %% [markdown]
# # **Bar Chart**

# %%
top5negara = df.groupby('country')['climate_risk_score'].mean().sort_values(ascending=False).head(5)

plt.figure(figsize=(10,6))
plt.bar(top5negara.index, top5negara.values)
plt.xlabel('Negara')
plt.ylabel('Climate Risk Score')
plt.title('Top 5 Negara dengan Risiko Iklim Tertinggi')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Grafik batang tersebut menampilkan lima negara dengan rata-rata *climate risk score* tertinggi yang dihitung dari rata-rata skor risiko iklim tiap negara lalu diurutkan dari yang paling tinggi. Visualisasi ini menunjukkan negara-negara yang paling rentan terhadap dampak perubahan iklim seperti peningkatan suhu, bencana alam, dan gangguan lingkungan.
#
# **Insight:** Negara dengan skor tertinggi memiliki tingkat kerentanan iklim yang lebih besar dibandingkan negara lainnya, sehingga berpotensi mengalami dampak lingkungan, sosial, dan ekonomi yang lebih signifikan akibat perubahan iklim.
#
# **Action:** Negara-negara tersebut perlu menjadi prioritas dalam upaya mitigasi dan adaptasi perubahan iklim, seperti memperkuat kebijakan lingkungan, meningkatkan sistem peringatan dini bencana, serta berinvestasi pada infrastruktur dan program ketahanan iklim.

# %% [markdown]
# # **Pie Chart**

# %%
plt.figure(figsize=(8, 6))
plt.pie(df['region'].value_counts(), labels=df['region'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold']) # colors (warna)
plt.title('Distribusi Jenis Kejadian Iklim Ekstrem')
plt.show()

# %% [markdown]
# Grafik pie tersebut menunjukkan distribusi data berdasarkan wilayah (*region*) dalam dataset perubahan iklim. Setiap bagian pie merepresentasikan proporsi jumlah data dari masing-masing wilayah, sehingga dapat terlihat kontribusi tiap region terhadap keseluruhan dataset.
#
# **Insight:** Wilayah dengan persentase terbesar menunjukkan bahwa data perubahan iklim lebih banyak tercatat atau terfokus di area tersebut, yang dapat mengindikasikan tingkat kejadian iklim yang lebih sering, perhatian penelitian yang lebih besar, atau ketersediaan data yang lebih lengkap dibandingkan wilayah lainnya.
#
# **Action:** Wilayah dengan proporsi data tinggi dapat dijadikan fokus utama dalam analisis dampak perubahan iklim dan penyusunan strategi mitigasi. Sementara itu, wilayah dengan proporsi lebih kecil perlu ditinjau kembali untuk memastikan apakah jumlah datanya memang sedikit atau masih terdapat keterbatasan dalam pengumpulan data, sehingga upaya peningkatan pemantauan dan pencatatan data iklim dapat dilakukan.

# %% [markdown]
# # **Line Chart**

# %%
trend_country = df.groupby('country')['temperature_change_c'].mean().sort_values(ascending=False).head(15)

plt.figure(figsize=(10,6))
plt.plot(trend_country.index, trend_country.values, marker='o')
plt.title('Perubahan Suhu di Beberapa Negara')
plt.xlabel('Negara')
plt.ylabel('Perubahan Suhu (°C)')
plt.grid(True)

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Grafik line chart menampilkan rata-rata perubahan suhu (temperature_change_c) pada 15 negara dengan nilai perubahan suhu tertinggi, yang diperoleh dari pengelompokan data berdasarkan negara lalu dihitung rata-ratanya dan diurutkan dari yang tertinggi.
#
# Insight: Negara dengan nilai perubahan suhu tertinggi menunjukkan peningkatan suhu yang lebih signifikan dibandingkan negara lain, yang dapat menjadi indikator meningkatnya dampak perubahan iklim di wilayah tersebut.
#
# Action: Negara-negara tersebut perlu menjadi prioritas dalam upaya mitigasi dan adaptasi perubahan iklim, seperti pengurangan emisi, pengembangan energi terbarukan, serta peningkatan kebijakan ketahanan lingkungan.

# %% [markdown]
# # **Histogram**

# %%
#Distribusi Perubahan Suhu

plt.figure(figsize=(8,5))
plt.hist(df['temperature_change_c'], bins=20, edgecolor='black')
plt.title('Distribusi Perubahan Suhu')
plt.xlabel('Perubahan Suhu (°C)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan **distribusi nilai perubahan suhu (*temperature_change_c*)** dalam dataset, dengan sumbu horizontal sebagai nilai perubahan suhu (°C) dan sumbu vertikal sebagai frekuensi kemunculan data pada tiap rentang nilai.
#
# **Insight:** Sebaran data pada histogram menunjukkan rentang perubahan suhu yang paling sering terjadi, sehingga dapat diketahui apakah perubahan suhu cenderung berada pada nilai tertentu atau memiliki variasi yang cukup besar.
#
# **Action:** Informasi ini dapat digunakan untuk memahami pola perubahan suhu secara umum serta menjadi dasar dalam analisis lebih lanjut terkait tren pemanasan dan dampaknya terhadap lingkungan.

# %% [markdown]
# # **Boxplot**

# %%
# Identifikasi 5 negara teratas berdasarkan jumlah data
top5negara = df['country'].value_counts().head(5).index
# Filter dataframe
df_top5_countries = df[df['country'].isin(top5negara)]
plt.figure(figsize=(12,7))
df_top5_countries.boxplot(
    column='climate_risk_score',
    by='country',
    ax=plt.gca(),
    grid=False,
    patch_artist=True,
    medianprops=dict(color='red')
)
plt.title('Distribusi Climate Risk Score di Top 5 Negara', fontsize=16)
plt.xlabel('Negara', fontsize=12)
plt.ylabel('Climate Risk Score', fontsize=12)

plt.xticks(rotation=45, ha='right')
plt.suptitle('')
plt.tight_layout()
plt.show()

# %% [markdown]
# Grafik boxplot menampilkan **distribusi nilai *climate risk score* pada lima negara dengan jumlah data terbanyak** dalam dataset, sehingga memperlihatkan perbandingan sebaran, median, serta variasi nilai risiko iklim pada masing-masing negara.
#
# **Insight:** Perbedaan posisi median dan lebar boxplot menunjukkan bahwa setiap negara memiliki tingkat risiko iklim dan variasi data yang berbeda, di mana negara dengan median lebih tinggi atau sebaran lebih luas cenderung memiliki tingkat kerentanan iklim yang lebih besar.
#
# **Action:** Negara dengan nilai median risiko tinggi atau variasi yang besar dapat menjadi fokus dalam analisis lanjutan dan perumusan strategi mitigasi serta adaptasi perubahan iklim untuk mengurangi potensi dampak yang lebih besar.

# %% [markdown]
# # **ScatterPlot**

# %%
# Scatter Plot (Matplotlib): CO2 Emissions vs Temperature Change
plt.figure(figsize=(10,6))
plt.scatter(df['co2_emissions_mt'], df['temperature_change_c'], alpha=0.7)

plt.title('Hubungan antara Emisi CO₂ dan Perubahan Suhu', fontsize=16)
plt.xlabel('Emisi CO₂ (Mt)', fontsize=12)
plt.ylabel('Perubahan Suhu (°C)', fontsize=12)

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Grafik scatter plot menunjukkan **hubungan antara emisi karbon dioksida (*CO₂ emissions*) dan perubahan suhu (*temperature change*)**, di mana setiap titik merepresentasikan satu observasi dengan emisi CO₂ pada sumbu horizontal dan perubahan suhu pada sumbu vertikal.
#
# **Insight:** Pola sebaran titik dapat menunjukkan adanya kecenderungan hubungan antara peningkatan emisi CO₂ dan perubahan suhu, yang mengindikasikan bahwa aktivitas emisi karbon berpotensi berkontribusi terhadap peningkatan suhu global.
#
# **Action:** Hasil ini dapat menjadi dasar untuk analisis lebih lanjut mengenai hubungan emisi dan perubahan suhu, serta mendukung upaya pengurangan emisi karbon melalui kebijakan lingkungan dan pengembangan energi yang lebih ramah lingkungan.

# %% [markdown]
# # **Bubble Chart**

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(
    x='co2_emissions_mt',
    y='temperature_change_c',
    size='population_affected_m',
    hue='region',
    data=df,
    sizes=(50,1000),
    alpha=0.7,
    palette='viridis'
)
plt.title('Emisi CO₂ vs Perubahan Suhu (Ukuran: Populasi Terdampak, Warna: Region)', fontsize=16)
plt.xlabel('Emisi CO₂ (Mt)', fontsize=12)
plt.ylabel('Perubahan Suhu (°C)', fontsize=12)
plt.grid(True)
plt.legend(title='Region', bbox_to_anchor=(1.05,1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# Grafik tersebut merupakan **scatter/bubble plot yang menunjukkan hubungan antara emisi CO₂ dan perubahan suhu**, di mana ukuran titik merepresentasikan **jumlah populasi terdampak** dan warna menunjukkan **wilayah (region)**.
#
# **Insight:** Sebaran titik menunjukkan bahwa perubahan suhu terjadi pada berbagai tingkat emisi CO₂ di berbagai wilayah. Beberapa titik dengan ukuran besar menandakan bahwa peningkatan suhu dapat berdampak pada populasi yang cukup besar, terutama pada wilayah tertentu.
#
# **Action:** Analisis ini dapat digunakan untuk mengidentifikasi wilayah dengan emisi tinggi dan populasi terdampak besar sehingga dapat menjadi prioritas dalam kebijakan pengurangan emisi, peningkatan mitigasi perubahan iklim, serta perlindungan terhadap masyarakat yang paling rentan terhadap dampaknya.

# %% [markdown]
# # **HeatMap**

# %%
plt.figure(figsize=(10,8))
sns.heatmap(
    df[['temperature_change_c','co2_emissions_mt','sea_level_rise_mm',
        'heatwave_days','wildfire_incidents','climate_risk_score',
        'population_affected_m']].corr(),
    annot=True,
    cmap='viridis',
    fmt='.2f'
)
plt.title('Korelasi Antar Variabel Perubahan Iklim')
plt.show()

# %% [markdown]
# Visualisasi **heatmap** digunakan untuk menampilkan korelasi antar variabel terkait perubahan iklim seperti *temperature_change_c*, *co2_emissions_mt*, *sea_level_rise_mm*, *heatwave_days*, *wildfire_incidents*, *climate_risk_score*, dan *population_affected_m*. Warna pada heatmap menunjukkan kekuatan hubungan antar variabel sehingga memudahkan identifikasi pola hubungan dalam data.
#
# **Insight:** Beberapa variabel menunjukkan korelasi yang lebih kuat dibandingkan yang lain, yang dapat mengindikasikan adanya keterkaitan antara faktor-faktor tertentu dalam fenomena perubahan iklim.
#
# **Action:** Hasil korelasi ini dapat digunakan sebagai dasar untuk analisis lanjutan, seperti mengidentifikasi faktor yang paling berpengaruh terhadap risiko iklim atau perubahan suhu.
